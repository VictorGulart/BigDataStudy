# %%
import pymongo
from pprint import pprint

# %%
# Connecting to the Server
conn = pymongo.MongoClient('localhost', 27017)

# Creating or connectin to the Database
db = conn['big_data_class']

# Creating or connecting to the Collection
coll = db.amazon_sample

# %%
# Filter by Customer
query = {'Customer': 'Ram Prasad' }
pprint(list(coll.find(query)))

# %%
# Filter by '_id'
coll.find_one({'_id':'C3'})
# Out:
# {'_id': 'C3',
#  'Customer': 'Raelynn Dodson',
#  'Gender': 'F',
#  'Age': 44,
#  'phone_number': {'$numberLong': '443482883256'},
#  'addresses': [{'_id': 'AD3',
#    'house': 3,
#    'street': 'Dickinson St',
#    'city': 'Manchester',
#    'post_code': 'M1 4LF',
#    'location': {'type': 'Point', 'coordinates': [53.47850891, -2.242348226]}}],
#  'current_orders': [{'_id': '20230104035938C3',
#    'date': {'$date': {'$numberLong': '1672804778000'}},
#    'order_status': 2,
#    'order_details': [{'product_id': 'PH1', 'quantity': 1, 'cost': 169}],
#    'total_cost': 169,
#    'partner_id': '',
#    'shipping_id': 'AD3',
#    'supplier_id': 'W1'},
#   {'_id': '20230104045148C3',
#    'date': {'$date': {'$numberLong': '1672807908000'}},
#    'order_status': 1,
#    'order_details': [{'product_id': 'FP2', 'quantity': 1, 'cost': 2.7},
#     {'product_id': 'FP1', 'quantity': 5, 'cost': 2}],
#    'total_cost': 210,
#    'partner_id': '',
#    'shipping_id': 'AD3',
#    'supplier_id': 'ST4'},
#   {'_id': '20230104054212C3',
#    'date': {'$date': {'$numberLong': '1672810932000'}},
#    'order_status': 2,
#    'total_cost': 11.48,
#    'partner_id': '',
#    'shipping_id': 'AD3',
#    'supplier_id': 'W1',
#    'order_details': [{'product_id': 'CD2', 'quantity': 1, 'cost': 11.48}]}],
#  'recommended_products': [{'product_id': 'FP10', 'avg_rating': 3.8},
#   {'product_id': 'PH4', 'avg_rating': 3.6}]}

# %%
# Filter by Age > 30
query = { 'Age' : {'$gt':30}}
pprint(list(coll.find(query)))
# Out:
# [{'Age': 51,
#   'Customer': 'Gunner Ferrell',
#   'Gender': 'M',
#   '_id': 'C1',
#   'addresses': [{'_id': 'AD1',
#                  'city': 'Manchester',
#                  'house': 27,
#                  'location': {'coordinates': [53.4702888668, -2.26459207339],
#                               'type': 'Point'},
#                  'post_code': 'M15 4RU',
#                  'street': 'Ellesmere St'}],
#   'current_orders': [{'_id': '20230104002920C1',
#                       'date': {'$date': {'$numberLong': '1672792160000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP1',
#                                          'quantity': 4},
#                                         {'cost': 2.7,
#                                          'product_id': 'FP2',
#                                          'quantity': 1}],
#                       'order_status': 3,
#                       'partner_id': '',
#                       'shipping_id': 'AD1',
#                       'supplier_id': 'ST1',
#                       'total_cost': 10.7},
#                      {'_id': '20230104032330C1',
#                       'date': {'$date': {'$numberLong': '1672802610000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP5',
#                                          'quantity': 2}],
#                       'order_status': 3,
#                       'partner_id': '',
#                       'shipping_id': 'AD1',
#                       'supplier_id': 'ST2',
#                       'total_cost': 4},
#                      {'_id': '20230109181700C2',
#                       'date': {'$date': {'$numberLong': '1673285460000'}},
#                       'order_details': [{'cost': 6,
#                                          'product_id': 'FP3',
#                                          'quantity': 3}],
#                       'order_status': 3,
#                       'partner_id': 'PA2',
#                       'shipping_id': 'AD2',
#                       'supplier_id': 'ST3',
#                       'total_cost': 6},
#                      {'_id': '20233101/09/23173100C1',
#                       'date': {'$date': {'$numberLong': '1673285460000'}},
#                       'order_details': [{'product_id': 'FP1'}],
#                       'order_status': 3,
#                       'partner_id': 'PA2',
#                       'shipping_id': 'AD1',
#                       'supplier_id': 'ST5',
#                       'total_cost': 6}],
#   'phone_number': {'$numberLong': '443454155475'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP10'},
#                            {'product_id': 'CD2', 'ratings': 4}]},
#  {'Age': 44,
#   'Customer': 'Raelynn Dodson',
#   'Gender': 'F',
#   '_id': 'C3',
#   'addresses': [{'_id': 'AD3',
#                  'city': 'Manchester',
#                  'house': 3,
#                  'location': {'coordinates': [53.47850891, -2.242348226],
#                               'type': 'Point'},
#                  'post_code': 'M1 4LF',
#                  'street': 'Dickinson St'}],
#   'current_orders': [{'_id': '20230104035938C3',
#                       'date': {'$date': {'$numberLong': '1672804778000'}},
#                       'order_details': [{'cost': 169,
#                                          'product_id': 'PH1',
#                                          'quantity': 1}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD3',
#                       'supplier_id': 'W1',
#                       'total_cost': 169},
#                      {'_id': '20230104045148C3',
#                       'date': {'$date': {'$numberLong': '1672807908000'}},
#                       'order_details': [{'cost': 2.7,
#                                          'product_id': 'FP2',
#                                          'quantity': 1},
#                                         {'cost': 2,
#                                          'product_id': 'FP1',
#                                          'quantity': 5}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD3',
#                       'supplier_id': 'ST4',
#                       'total_cost': 210},
#                      {'_id': '20230104054212C3',
#                       'date': {'$date': {'$numberLong': '1672810932000'}},
#                       'order_details': [{'cost': 11.48,
#                                          'product_id': 'CD2',
#                                          'quantity': 1}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD3',
#                       'supplier_id': 'W1',
#                       'total_cost': 11.48}],
#   'phone_number': {'$numberLong': '443482883256'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP10'},
#                            {'avg_rating': 3.6, 'product_id': 'PH4'}]},
#  {'Age': 43,
#   'Customer': 'Yazmin Hughes',
#   'Gender': 'F',
#   '_id': 'C4',
#   'addresses': [{'_id': 'AD4',
#                  'city': 'Manchester',
#                  'house': 'Manchester Apartment 104',
#                  'location': {'coordinates': [53.47435691, -2.242684794],
#                               'type': 'Point'},
#                  'post_code': 'M1 5EE',
#                  'street': '60 Oxford St'}],
#   'current_orders': [{'_id': '20230104062322C4',
#                       'date': {'$date': {'$numberLong': '1672813402000'}},
#                       'order_details': [{'cost': 5,
#                                          'product_id': 'FP12',
#                                          'quantity': 5}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD4',
#                       'supplier_id': 'ST5',
#                       'total_cost': 25},
#                      {'_id': '20230104070917C4',
#                       'date': {'$date': {'$numberLong': '1672816157000'}},
#                       'order_details': [{'cost': 58.99,
#                                          'product_id': 'HA1',
#                                          'quantity': 1}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD4',
#                       'supplier_id': 'W1',
#                       'total_cost': 58.99}],
#   'phone_number': {'$numberLong': '446180152448'},
#   'recommended_products': [{'avg_rating': 3.4, 'product_id': 'B10'},
#                            {'avg_rating': 4, 'product_id': 'HA3'}]},
#  {'Age': 64,
#   'Customer': 'Jamarcus Montgomery',
#   'Gender': 'M',
#   '_id': 'C6',
#   'addresses': [{'_id': 'AD6',
#                  'city': 'Manchester',
#                  'house': 6,
#                  'location': {'coordinates': [53.47999262, -2.236578948],
#                               'type': 'Point'},
#                  'post_code': 'M1 3ED',
#                  'street': 'Minshull St'}],
#   'current_orders': [{'_id': '20230104083607C6',
#                       'date': {'$date': {'$numberLong': '1672821367000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP3',
#                                          'quantity': 5}],
#                       'order_status': 4,
#                       'partner_id': 'PA3',
#                       'shipping_id': 'AD6',
#                       'supplier_id': 'ST1',
#                       'total_cost': 10},
#                      {'_id': '20230104084644C6',
#                       'date': {'$date': {'$numberLong': '1672822004000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP5',
#                                          'quantity': 2}],
#                       'order_status': 3,
#                       'partner_id': 'PA3',
#                       'shipping_id': 'AD6',
#                       'supplier_id': 'ST2',
#                       'total_cost': 4}],
#   'phone_number': {'$numberLong': '448832254583'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP10'},
#                            {'avg_rating': 3.6, 'product_id': 'PH4'}]},
#  {'Age': 47,
#   'Customer': 'Kelsey Brandt',
#   'Gender': 'F',
#   '_id': 'C8',
#   'addresses': [{'_id': 'AD8',
#                  'city': 'Manchester',
#                  'house': 9,
#                  'location': {'coordinates': [53.4739587, -2.247152235],
#                               'type': 'Point'},
#                  'post_code': 'M1 5JB',
#                  'street': 'Whitworth St W'}],
#   'current_orders': [{'_id': '20230104100253C8',
#                       'date': {'$date': {'$numberLong': '1672826573000'}},
#                       'order_details': [{'cost': 20.65,
#                                          'product_id': 'CD8',
#                                          'quantity': 1}],
#                       'order_status': 4,
#                       'partner_id': 'PA1',
#                       'shipping_id': 'AD8',
#                       'supplier_id': 'W1',
#                       'total_cost': 20.65},
#                      {'_id': '20230104111320C8',
#                       'date': {'$date': {'$numberLong': '1672830800000'}},
#                       'order_details': [{'cost': 14,
#                                          'product_id': 'B4',
#                                          'quantity': 2}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD8',
#                       'supplier_id': 'W2',
#                       'total_cost': 28}],
#   'phone_number': {'$numberLong': '447531225175'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'HA10'},
#                            {'avg_rating': 4.2, 'product_id': 'B2'}]},
#  {'Age': 45,
#   'Customer': 'Billy Ross',
#   'Gender': 'M',
#   '_id': 'C10',
#   'addresses': [{'_id': 'AD10',
#                  'city': 'Manchester',
#                  'house': 36,
#                  'location': {'coordinates': [53.47182187, -2.249197681],
#                               'type': 'Point'},
#                  'post_code': 'M15 4TH',
#                  'street': 'City Rd E'}],
#   'current_orders': [{'_id': '20230104142337C10',
#                       'date': {'$date': {'$numberLong': '1672842217000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP5',
#                                          'quantity': 2}],
#                       'order_status': 4,
#                       'partner_id': 'PA2',
#                       'shipping_id': 'AD10',
#                       'supplier_id': 'ST2',
#                       'total_cost': 4},
#                      {'_id': '20230104142757C10',
#                       'date': {'$date': {'$numberLong': '1672842477000'}},
#                       'order_details': [{'cost': 7.46,
#                                          'product_id': 'CD5',
#                                          'quantity': 1}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD10',
#                       'supplier_id': 'W1',
#                       'total_cost': 7.46}],
#   'phone_number': {'$numberLong': '449575146991'},
#   'recommended_products': [{'avg_rating': 3.4, 'product_id': 'CD1'},
#                            {'avg_rating': 3.8, 'product_id': 'HA10'}]},
#  {'Age': 64,
#   'Customer': 'Lucian Cohen',
#   'Gender': 'F',
#   '_id': 'C12',
#   'addresses': [{'_id': 'AD12',
#                  'city': 'Manchester',
#                  'house': 'Downtown Apartment 405',
#                  'location': {'coordinates': [53.47379226, -2.266542294],
#                               'type': 'Point'},
#                  'post_code': 'M5 4YH',
#                  'street': '7-9 Woden St'}],
#   'current_orders': [{'_id': '20230104154828C12',
#                       'date': {'$date': {'$numberLong': '1672847308000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP1',
#                                          'quantity': 3}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD12',
#                       'supplier_id': 'ST1',
#                       'total_cost': 6},
#                      {'_id': '20230104162435C12',
#                       'date': {'$date': {'$numberLong': '1672849475000'}},
#                       'order_details': [{'cost': 4,
#                                          'product_id': 'FP10',
#                                          'quantity': 5}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD12',
#                       'supplier_id': 'ST2',
#                       'total_cost': 20}],
#   'phone_number': {'$numberLong': '444694363523'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP10'},
#                            {'avg_rating': 3.8, 'product_id': 'HA2'}]},
#  {'Age': 58,
#   'Customer': 'Rowan Fox',
#   'Gender': 'M',
#   '_id': 'C13',
#   'addresses': [{'_id': 'AD13',
#                  'city': 'Manchester',
#                  'house': 'Circle Square Apartment 321',
#                  'location': {'coordinates': [53.47255984, -2.236631167],
#                               'type': 'Point'},
#                  'post_code': 'M1 7GB',
#                  'street': '7 Symphony Park'},
#                 {'_id': 'AD14',
#                  'city': 'Manchester',
#                  'house': 42,
#                  'location': {'coordinates': [53.47198948, -2.248974858],
#                               'type': 'Point'},
#                  'post_code': 'M15 4QF',
#                  'street': 'City Rd E'}],
#   'current_orders': [{'_id': '20230104164331C13',
#                       'date': {'$date': {'$numberLong': '1672850611000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP9',
#                                          'quantity': 6}],
#                       'order_status': 4,
#                       'partner_id': 'PA3',
#                       'shipping_id': 'AD13',
#                       'supplier_id': 'ST2',
#                       'total_cost': 12},
#                      {'_id': '20230104171338C13',
#                       'date': {'$date': {'$numberLong': '1672852418000'}},
#                       'order_details': [{'cost': 3,
#                                          'product_id': 'FP13',
#                                          'quantity': 2}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD13',
#                       'supplier_id': 'W1',
#                       'total_cost': 6}],
#   'phone_number': {'$numberLong': '447885651241'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP8'},
#                            {'avg_rating': 3.6, 'product_id': 'PH4'}]},
#  {'Age': 33,
#   'Customer': 'Brice Copeland',
#   'Gender': 'M',
#   '_id': 'C14',
#   'addresses': [{'_id': 'AD15',
#                  'city': 'Manchester',
#                  'house': 'Thomas House 108',
#                  'location': {'coordinates': [53.48445305, -2.23749638],
#                               'type': 'Point'},
#                  'post_code': 'M4 1EX',
#                  'street': 'Thomas St'}],
#   'current_orders': [{'_id': '20230104175610C14',
#                       'date': {'$date': {'$numberLong': '1672854970000'}},
#                       'order_details': [{'cost': 8,
#                                          'product_id': 'B3',
#                                          'quantity': 1}],
#                       'order_status': 3,
#                       'partner_id': '',
#                       'shipping_id': 'AD15',
#                       'supplier_id': 'W1',
#                       'total_cost': 8},
#                      {'_id': '20230104181037C14',
#                       'date': {'$date': {'$numberLong': '1672855837000'}},
#                       'order_details': [{'cost': 7.46,
#                                          'product_id': 'CD5',
#                                          'quantity': 1}],
#                       'order_status': 4,
#                       'partner_id': 'PA2',
#                       'shipping_id': 'AD15',
#                       'supplier_id': 'W2',
#                       'total_cost': 7.46}],
#   'phone_number': {'$numberLong': '446933952521'},
#   'recommended_products': [{'avg_rating': 4.2, 'product_id': 'B2'},
#                            {'avg_rating': 3.8, 'product_id': 'FP10'}]},
#  {'Age': 66,
#   'Customer': 'Calvin Carlson',
#   'Gender': 'M',
#   '_id': 'C15',
#   'addresses': [{'_id': 'AD16',
#                  'city': 'Manchester',
#                  'house': 'Botanica Apartment 406',
#                  'location': {'coordinates': [53.46764284, -2.264848358],
#                               'type': 'Point'},
#                  'post_code': 'M15 4YS',
#                  'street': '343 Chester Road'}],
#   'current_orders': [{'_id': '20230104183531C15',
#                       'date': {'$date': {'$numberLong': '1672857331000'}},
#                       'order_details': [{'cost': 14.92,
#                                          'product_id': 'CD6',
#                                          'quantity': 1}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD16',
#                       'supplier_id': 'W1',
#                       'total_cost': 14.92},
#                      {'_id': '20230104184145C15',
#                       'date': {'$date': {'$numberLong': '1672857705000'}},
#                       'order_details': [{'cost': 29,
#                                          'product_id': 'HA5',
#                                          'quantity': 1}],
#                       'order_status': 1,
#                       'partner_id': '',
#                       'shipping_id': 'AD16',
#                       'supplier_id': 'W1',
#                       'total_cost': 29}],
#   'phone_number': {'$numberLong': '448193919245'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'HA2'},
#                            {'avg_rating': 4.2, 'product_id': 'B2'}]},
#  {'Age': 38,
#   'Customer': 'Patience Valentine',
#   'Gender': 'F',
#   '_id': 'C17',
#   'addresses': [{'_id': 'AD18',
#                  'city': 'Manchester',
#                  'house': 290,
#                  'location': {'coordinates': [53.45466109, -2.207181547],
#                               'type': 'Point'},
#                  'post_code': 'M14 5HA',
#                  'street': 'Dickenson Road'}],
#   'current_orders': [{'_id': '20230104192023C17',
#                       'date': {'$date': {'$numberLong': '1672860023000'}},
#                       'order_details': [{'cost': 61.75,
#                                          'product_id': 'HA9',
#                                          'quantity': 1}],
#                       'order_status': 3,
#                       'partner_id': '',
#                       'shipping_id': 'AD18',
#                       'supplier_id': 'W1',
#                       'total_cost': 61.75},
#                      {'_id': '20230104194512C17',
#                       'date': {'$date': {'$numberLong': '1672861512000'}},
#                       'order_details': [{'cost': 16.99,
#                                          'product_id': 'B7',
#                                          'quantity': 8}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD18',
#                       'supplier_id': 'W3',
#                       'total_cost': 135.92}],
#   'phone_number': {'$numberLong': '448240719966'},
#   'recommended_products': [{'avg_rating': 4.2, 'product_id': 'B2'},
#                            {'avg_rating': 3.8, 'product_id': 'FP10'}]},
#  {'Age': 70,
#   'Customer': 'Aubree Holland',
#   'Gender': 'M',
#   '_id': 'C18',
#   'addresses': [{'_id': 'AD19',
#                  'city': 'Manchester',
#                  'house': 144,
#                  'location': {'coordinates': [53.46303432, -2.218282878],
#                               'type': 'Point'},
#                  'post_code': 'M13 9LU',
#                  'street': 'Plymouth Grove'}],
#   'current_orders': [{'_id': '20230104195830C18',
#                       'date': {'$date': {'$numberLong': '1672862310000'}},
#                       'order_details': [{'cost': 169,
#                                          'product_id': 'PH1',
#                                          'quantity': 1}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD19',
#                       'supplier_id': 'W1',
#                       'total_cost': 169},
#                      {'_id': '20230104204208C18',
#                       'date': {'$date': {'$numberLong': '1672864928000'}},
#                       'order_details': [{'cost': 18.2,
#                                          'product_id': 'CD9',
#                                          'quantity': 2}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD19',
#                       'supplier_id': 'W1',
#                       'total_cost': 36.4}],
#   'phone_number': {'$numberLong': '448137575603'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'HA2'},
#                            {'avg_rating': 3.6, 'product_id': 'FP1'}]},
#  {'Age': 50,
#   'Customer': 'Ram Prasad',
#   'Gender': 'M',
#   '_id': 'C19',
#   'addresses': [{'_id': 'AD20',
#                  'city': 'Manchester',
#                  'house': 5,
#                  'location': {'coordinates': [53.46546566, -2.261863026],
#                               'type': 'Point'},
#                  'post_code': 'M15 4SG',
#                  'street': 'Lucy St'},
#                 {'_id': 'AD21',
#                  'city': 'Manchester',
#                  'house': 4,
#                  'location': {'coordinates': [53.46406425, -2.241031337],
#                               'type': 'Point'},
#                  'post_code': 'M15 6HD',
#                  'street': 'Eyre St'}],
#   'current_orders': [{'_id': '20230104210846C19',
#                       'date': {'$date': {'$numberLong': '1672866526000'}},
#                       'order_details': [{'cost': 599,
#                                          'product_id': 'PH7',
#                                          'quantity': 4},
#                                         {'cost': 8.28,
#                                          'product_id': 'CD10',
#                                          'quantity': 5}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD20',
#                       'supplier_id': 'W1',
#                       'total_cost': 2437.4},
#                      {'_id': '20230104212616C19',
#                       'date': {'$date': {'$numberLong': '1672867576000'}},
#                       'order_details': [{'cost': 13.99,
#                                          'product_id': 'B6',
#                                          'quantity': 1},
#                                         {'cost': 769,
#                                          'product_id': 'PH6',
#                                          'quantity': 1}],
#                       'order_status': 3,
#                       'partner_id': '',
#                       'shipping_id': 'AD21',
#                       'supplier_id': 'W1',
#                       'total_cost': 782.99}],
#   'phone_number': {'$numberLong': '445866104074'},
#   'recommended_products': [{'avg_rating': 3.8, 'product_id': 'FP10'},
#                            {'avg_rating': 3.6, 'product_id': 'PH4'}]},
#  {'Age': 59,
#   'Customer': 'Mark Mulldon',
#   'Gender': 'M',
#   '_id': 'C20',
#   'addresses': [{'_id': 'AD22',
#                  'city': 'Manchester',
#                  'house': 2,
#                  'location': {'coordinates': [53.46931183, -2.242109147],
#                               'type': 'Point'},
#                  'post_code': 'M15 6DA',
#                  'street': 'Knowles Place'}],
#   'current_orders': [{'_id': '20230104230118C20',
#                       'date': {'$date': {'$numberLong': '1672873278000'}},
#                       'order_details': [{'cost': 2,
#                                          'product_id': 'FP9',
#                                          'quantity': 3},
#                                         {'cost': 2,
#                                          'product_id': 'FP7',
#                                          'quantity': 4}],
#                       'order_status': 2,
#                       'partner_id': '',
#                       'shipping_id': 'AD22',
#                       'supplier_id': 'ST1',
#                       'total_cost': 14},
#                      {'_id': '20230104232544C20',
#                       'date': {'$date': {'$numberLong': '1672874744000'}},
#                       'order_details': [{'cost': 849,
#                                          'product_id': 'PH9',
#                                          'quantity': 1}],
#                       'order_status': 4,
#                       'partner_id': 'PA3',
#                       'shipping_id': 'AD22',
#                       'supplier_id': 'W3',
#                       'total_cost': 849}],
#   'phone_number': {'$numberLong': '445219432797'},
#   'recommended_products': [{'avg_rating': 3.6, 'product_id': 'FP1'},
#                            {'avg_rating': 4, 'product_id': 'CD2'}]}]

# %%
# Filter count the number of Customers with Age > 30
query = {'Age': {'$gt':30} }
pprint(coll.count_documents(query)) # Count
# Out:
# 14

# %%
# Get the average age of the customers
pipeline = [
        {'$group': {
            '_id':None, # to group everything into one
            'average_age': {'$avg' : '$Age'} # creating the average variable
        }}
    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'_id': None, 'average_age': 44.1}]

# %%
#####################

### DOES NOT WORK ###

#####################


# $first returns the first document instance and NOT the correct customer with highest purchase


projection = {
    '_id': 0,
    'Customer': 1,
    'highest purchase': 1
}

pipeline = [
        { '$unwind': '$current_orders' },
        {'$group': {
            '_id':None, # to group everything into one
            'Customer' : { '$first': '$Customer'}, # $first returns the first document instance and NOT the correct customer with highest 
            'highest purchase': {'$max' : '$current_orders.total_cost'} # creating the average variable
        }},
        {
            '$project': projection
        }
    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'Customer': 'Gunner Ferrell', 'highest purchase': 2437.4}]

# %%
#####################

##### DOES WORK #####

#####################

projection = {
    '_id': 0,
    'Customer': 1,
    'highest purchase': {'$max' : '$current_orders.total_cost'} 
}

sort = {
    'highest purchase': -1
}

limit = {
    '$limit': 1
}

pipeline = [
        {
            '$project': projection
        },
        {
            '$sort': sort
        },
        {**limit}

    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'Customer': 'Ram Prasad', 'highest purchase': 2437.4}]

# %%
#####################

##### DOES WORK #####

#####################


# This uses $reduce

projection = {
    '_id': 0,
    'Customer': 1,
    'highest purchase': {'$reduce' : {
        'input':'$current_orders',
        'initialValue': 0,
        'in': {
            '$cond':{
                'if': { '$gt': ['$$this.total_cost', '$$value']},
                'then': '$$this.total_cost',
                'else': '$$value'
            }
        }
    }} 
}

pipeline = [
        {
            '$project': projection
        },
        {
            '$sort': {'highest purchase': -1}
        },
        {
            '$limit': 1
        }
    ]

lst = list(coll.aggregate(pipeline))

if lst:
    pprint( lst)
# Out:
# [{'Customer': 'Ram Prasad', 'highest purchase': 2437.4}]

# %%
#  Get the total amount of product quantities sold by product using $unwind and $sort
pipeline = [
        {'$unwind': '$current_orders'},
        {'$unwind': '$current_orders.order_details'},
        {'$group': {
            "_id" : "$current_orders.order_details.product_id",
            'total_quantity': {'$sum': "$current_orders.order_details.quantity"}
        }},
        {
            '$sort' : {'_id' : 1}
        }
    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'_id': 'B3', 'total_quantity': 1},
#  {'_id': 'B4', 'total_quantity': 2},
#  {'_id': 'B6', 'total_quantity': 1},
#  {'_id': 'B7', 'total_quantity': 8},
#  {'_id': 'B9', 'total_quantity': 1},
#  {'_id': 'CD1', 'total_quantity': 1},
#  {'_id': 'CD10', 'total_quantity': 9},
#  {'_id': 'CD2', 'total_quantity': 1},
#  {'_id': 'CD5', 'total_quantity': 2},
#  {'_id': 'CD6', 'total_quantity': 1},
#  {'_id': 'CD8', 'total_quantity': 1},
#  {'_id': 'CD9', 'total_quantity': 2},
#  {'_id': 'FP1', 'total_quantity': 16},
#  {'_id': 'FP10', 'total_quantity': 10},
#  {'_id': 'FP12', 'total_quantity': 5},
#  {'_id': 'FP13', 'total_quantity': 2},
#  {'_id': 'FP2', 'total_quantity': 5},
#  {'_id': 'FP3', 'total_quantity': 10},
#  {'_id': 'FP4', 'total_quantity': 4},
#  {'_id': 'FP5', 'total_quantity': 6},
#  {'_id': 'FP7', 'total_quantity': 4},
#  {'_id': 'FP9', 'total_quantity': 9},
#  {'_id': 'HA1', 'total_quantity': 1},
#  {'_id': 'HA3', 'total_quantity': 2},
#  {'_id': 'HA5', 'total_quantity': 1},
#  {'_id': 'HA6', 'total_quantity': 1},
#  {'_id': 'HA9', 'total_quantity': 2},
#  {'_id': 'PH1', 'total_quantity': 2},
#  {'_id': 'PH6', 'total_quantity': 1},
#  {'_id': 'PH7', 'total_quantity': 4},
#  {'_id': 'PH9', 'total_quantity': 1}]

# %%
# Total purchase by customer
pipeline = [
        {'$project': {
            "_id" : "$_id",
            'Customer' : "$Customer",
            'Total purchase': {'$sum': "$current_orders.total_cost"}
        }},
        { '$sort': { 'Customer': 1 }}
    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'Customer': 'Alyvia Mccormick', 'Total purchase': 157.37, '_id': 'C16'},
#  {'Customer': 'Aubree Holland', 'Total purchase': 205.4, '_id': 'C18'},
#  {'Customer': 'Billy Ross', 'Total purchase': 11.46, '_id': 'C10'},
#  {'Customer': 'Brice Copeland', 'Total purchase': 15.46, '_id': 'C14'},
#  {'Customer': 'Calvin Carlson', 'Total purchase': 43.92, '_id': 'C15'},
#  {'Customer': 'Charity Dunn', 'Total purchase': 18.09, '_id': 'C7'},
#  {'Customer': 'Gunner Ferrell', 'Total purchase': 26.7, '_id': 'C1'},
#  {'Customer': 'Jairo Fitzgerald', 'Total purchase': 26, '_id': 'C11'},
#  {'Customer': 'Jamarcus Montgomery', 'Total purchase': 14, '_id': 'C6'},
#  {'Customer': 'Kelsey Brandt', 'Total purchase': 48.65, '_id': 'C8'},
#  {'Customer': 'Kylee Wang', 'Total purchase': 28.47, '_id': 'C9'},
#  {'Customer': 'Lillie Costa', 'Total purchase': 23.6, '_id': 'C2'},
#  {'Customer': 'Lucian Cohen', 'Total purchase': 26, '_id': 'C12'},
#  {'Customer': 'Mark Mulldon', 'Total purchase': 863, '_id': 'C20'},
#  {'Customer': 'Patience Valentine', 'Total purchase': 197.67, '_id': 'C17'},
#  {'Customer': 'Raelynn Dodson', 'Total purchase': 390.48, '_id': 'C3'},
#  {'Customer': 'Ram Prasad', 'Total purchase': 3220.3900000000003, '_id': 'C19'},
#  {'Customer': 'Ray Mcdaniel',
#   'Total purchase': 103.22999999999999,
#   '_id': 'C5'},
#  {'Customer': 'Rowan Fox', 'Total purchase': 18, '_id': 'C13'},
#  {'Customer': 'Yazmin Hughes',
#   'Total purchase': 83.99000000000001,
#   '_id': 'C4'}]

# %%
# Average purchase
pipeline = [
        {'$group': {
            "_id" : None,
            'Total purchase': {'$avg': {'$sum': "$current_orders.total_cost"}}
        }}
    ]

pprint( list(coll.aggregate(pipeline)) )
# Out:
# [{'Total purchase': 276.094, '_id': None}]
