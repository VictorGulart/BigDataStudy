# %%
import numpy as np

# %%
a = np.array([[1,4,2], [3,-1,0]])
b = np.array([[2,5],[2,0],[-1,3]])

# %%
# matrix multiplication
np.dot(a,b)
# Out:
# array([[ 8, 11],
#        [ 4, 15]])

# %%
# scalar multiplication
b * 5
# Out:
# array([[10, 25],
#        [10,  0],
#        [-5, 15]])

# %%
a1 = np.array([[1,2], [3,4]])
a2 = np.array([[1,1], [2,2]])

# %%
a1 + a2
# Out:
# array([[2, 3],
#        [5, 6]])
